# %% [markdown]
# # nitric oxide (NOX) µg/m3
# # hour values
# # Frankfurter Allee

# %%
# import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime  
import calendar
import pymysql
import sqlalchemy
from getpass import getpass

# %%
# load csv-file
data = pd.read_csv('ber_nox_20220318-20230318 stundenwerte.csv')

# set variables
title = 'nitric oxide (NOX) µg/m3'
title2 = 'nitric oxide'
period = 'from 2022-03-18 to 2023-03-18'
title3 = 'nitric_oxide_nox_fa_hour'
unit = 'µg/m3'
color = 'orange'
data
# Out:
#               datetime  nitric_oxide_nox_µg_per_m3
# 0     18.03.2022 10:00                        20.0
# 1     18.03.2022 11:00                        16.0
# 2     18.03.2022 12:00                        14.0
# 3     18.03.2022 13:00                        16.0
# 4     18.03.2022 14:00                        13.0
# ...                ...                         ...
# 8754  18.03.2023 05:00                        25.0
# 8755  18.03.2023 06:00                        31.0
# 8756  18.03.2023 07:00                        47.0
# 8757  18.03.2023 08:00                        55.0
# 8758  18.03.2023 09:00                        69.0
#
# [8759 rows x 2 columns]

# %% [markdown]
# # format and add time-columns

# %%
data["datetime"] = pd.to_datetime(data["datetime"], dayfirst = True)

# %%
def hr_func(ts):
    return ts.hour

data['time_hour'] = data['datetime'].apply(hr_func)

# %%
data["day_number"] = data["datetime"].apply(lambda x: datetime.datetime.weekday(x))

# %%
# data['day_name'] = data['datetime'].dt.day_name()

# %%
data['month_number'] = pd.DatetimeIndex(data['datetime']).month

# %%
# data['month_name'] = data['month_number'].apply(lambda x: calendar.month_abbr[x])

# %%
data['year'] = pd.DatetimeIndex(data['datetime']).year

# %%
data.head()
# Out:
#              datetime  nitric_oxide_nox_µg_per_m3  time_hour  day_number  \
# 0 2022-03-18 10:00:00                        20.0         10           4
# 1 2022-03-18 11:00:00                        16.0         11           4
# 2 2022-03-18 12:00:00                        14.0         12           4
# 3 2022-03-18 13:00:00                        16.0         13           4
# 4 2022-03-18 14:00:00                        13.0         14           4
#
#    month_number  year
# 0             3  2022
# 1             3  2022
# 2             3  2022
# 3             3  2022
# 4             3  2022

# %%
plt.figure(figsize=(22,8))
sns.lineplot(x="datetime", y="nitric_oxide_nox_µg_per_m3",
             data=data, color=color).set(title=f"""{title}
{period}""")
# Out:
# [Text(0.5, 1.0, 'nitric oxide (NOX) µg/m3\nfrom 2022-03-18 to 2023-03-18')]

# %% [markdown]
# # set min and max limit

# %%
max_limit = 110
min_limit = 30
data_max = data[data['nitric_oxide_nox_µg_per_m3'] >= max_limit]
data_min = data[data['nitric_oxide_nox_µg_per_m3'] <= min_limit]
count_rows_max = data_max.shape[0]
count_rows_min = data_min.shape[0]
count_rows = data.shape[0]

# %% [markdown]
# # general data

# %%
data.describe(percentiles=[]).applymap('{:.2f}'.format)
# Out:
#       nitric_oxide_nox_µg_per_m3 time_hour day_number month_number     year
# count                    8746.00   8759.00    8759.00      8759.00  8759.00
# mean                       44.89     11.50       3.00         6.53  2022.21
# std                        38.73      6.92       2.00         3.45     0.41
# min                         2.00      0.00       0.00         1.00  2022.00
# 50%                        34.00     12.00       3.00         7.00  2022.00
# max                       430.00     23.00       6.00        12.00  2023.00

# %%
plt.title(f"""{title} - value count
{period}
total number of records: {count_rows}""")
data["nitric_oxide_nox_µg_per_m3"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color, figsize=(18,5))
# data["carbon_monoxide_mg_per_m3"].value_counts(dropna=False).sort_index(ascending=True)
# Out:
# <AxesSubplot:title={'center':'nitric oxide (NOX) µg/m3 - value count\nfrom 2022-03-18 to 2023-03-18\ntotal number of records: 8759'}>

# %%
for i in range(0, 24):
    data_hour = data[data.time_hour == i]
    count_rows_hour = data_hour.shape[0]
    plt.title(f"""value count for {i} o'clock: {title} (all data)
{period}
total number of records: {count_rows_hour}""")
    data_hour["nitric_oxide_nox_µg_per_m3"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color, figsize=(18,5), ylim=(0,25))
    plt.show()

# %%
print("weekday 0 = monday; weekday 6 = sunday")
for i in range(0, 7):
    data_weekday = data[data.day_number == i]
    count_rows_weekday = data_weekday.shape[0]
    plt.title(f"""for day {i} value count: {title}
{period}
total number of records: {count_rows_weekday}""")
    data_weekday["nitric_oxide_nox_µg_per_m3"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color, figsize=(18,5), ylim=(0,40))
    plt.show()
# Out:
# weekday 0 = monday; weekday 6 = sunday

# %%
print("month 1 = January; month 12 = December")
for i in range(1, 13):
    data_month = data[data.month_number == i]
    count_rows_month = data_weekday.shape[0]
    plt.title(f"""for month {i} value count: {title}
{period}""")
    data_month["nitric_oxide_nox_µg_per_m3"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color, figsize=(18,5), ylim=(0,50))
    plt.show()
# Out:
# month 1 = January; month 12 = December

# %% [markdown]
# # values >= max limit

# %%
plt.title(f"""monthly value count: {title2}>={max_limit} {unit}
from january (1) to december (12)
{period}
total number of records: {count_rows_max}""")
data_max["month_number"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color)
# Out:
# <AxesSubplot:title={'center':'monthly value count: nitric oxide>=110 µg/m3\nfrom january (1) to december (12)\nfrom 2022-03-18 to 2023-03-18\ntotal number of records: 559'}>

# %%
plt.title(f"""weekday value count: {title2}>={max_limit} {unit}
from monday (0) to sunday (6)
{period}
total number of records: {count_rows_max}""")
data_max["day_number"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color)
# Out:
# <AxesSubplot:title={'center':'weekday value count: nitric oxide>=110 µg/m3\nfrom monday (0) to sunday (6)\nfrom 2022-03-18 to 2023-03-18\ntotal number of records: 559'}>

# %%
plt.title(f"""hour of the day value count: {title2}>={max_limit} {unit}
{title2}
{period}
total number of records: {count_rows_max}""")
data_max["time_hour"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color)
# Out:
# <AxesSubplot:title={'center':'hour of the day value count: nitric oxide>=110 µg/m3\nnitric oxide\nfrom 2022-03-18 to 2023-03-18\ntotal number of records: 559'}>

# %% [markdown]
# # values <= min limit

# %%
plt.title(f"""weekday value count: {title2}<={min_limit} {unit}
from monday (0) to sunday (6)
{period}
total number of records: {count_rows_min}""")
data_min["day_number"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color)
# Out:
# <AxesSubplot:title={'center':'weekday value count: nitric oxide<=30 µg/m3\nfrom monday (0) to sunday (6)\nfrom 2022-03-18 to 2023-03-18\ntotal number of records: 3916'}>

# %%
plt.title(f"""hour of the day value count: {title2}<={min_limit} {unit}
{period}
total number of records: {count_rows_min}""")
data_min["time_hour"].value_counts(dropna=False).sort_index(ascending=True).plot.bar(color=color)
# Out:
# <AxesSubplot:title={'center':'hour of the day value count: nitric oxide<=30 µg/m3\nfrom 2022-03-18 to 2023-03-18\ntotal number of records: 3916'}>

# %%
# MySQL Workbench password
password = getpass()
# Out:
# ········

# %%
# save sql-file
connection_string = f'mysql+pymysql://root:{password}@localhost/air_pollution'
engine = sqlalchemy.create_engine(connection_string)
data.to_sql(name=title3, con=engine, if_exists='replace', index=True, index_label=None)
# Out:
# 8759
